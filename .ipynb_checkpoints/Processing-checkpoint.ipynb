# %% [markdown]
# ## ①データの事前確認

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error

train = pd.read_csv("./all/train.csv")
test = pd.read_csv("./all/test.csv")

train = pd.read_csv("./all/train.csv")

train= pd.read_csv("./all/train.csv")

# %%
train.head()
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_shape = train.shape
test_shape = test.shape

# %%
print(train_shape)
# Out:
# (891, 12)

# %%
print(test_shape)
# Out:
# (418, 11)

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
def missing_value(df):
    null_val = df.isnull().sum()
    percent = 100 * df.isnull().sum()/len(df)
    missing_table = pd.concat([null_val, percent], axis=1)
    missing_table_ren_colums = missing_table.rename(
    columns = {0:"欠損数", 1:"%"})
    return missing_table_ren_colums

# %%
missing_value(train)
# Out:
#              欠損数          %
# PassengerId    0   0.000000
# Survived       0   0.000000
# Pclass         0   0.000000
# Name           0   0.000000
# Sex            0   0.000000
# Age          177  19.865320
# SibSp          0   0.000000
# Parch          0   0.000000
# Ticket         0   0.000000
# Fare           0   0.000000
# Cabin        687  77.104377
# Embarked       2   0.224467

# %%
missing_value(test)
# Out:
#              欠損数          %
# PassengerId    0   0.000000
# Pclass         0   0.000000
# Name           0   0.000000
# Sex            0   0.000000
# Age           86  20.574163
# SibSp          0   0.000000
# Parch          0   0.000000
# Ticket         0   0.000000
# Fare           1   0.239234
# Cabin        327  78.229665
# Embarked       0   0.000000

# %% [markdown]
# # ②データ前処理

# %%
#欠損値に中央値を入れる
#欠損値に代替する値を入れる
# train["Age"] = train["Age"].fillna(train["Age"].median())
train["Age"] = train["Age"].fillna(train["Age"].median())

train["Embarked"] = train["Embarked"].fillna("S")

missing_value(train)
# Out:
#              欠損数          %
# PassengerId    0   0.000000
# Survived       0   0.000000
# Pclass         0   0.000000
# Name           0   0.000000
# Sex            0   0.000000
# Age            0   0.000000
# SibSp          0   0.000000
# Parch          0   0.000000
# Ticket         0   0.000000
# Fare           0   0.000000
# Cabin        687  77.104377
# Embarked       0   0.000000

# %%
#カテゴリカルデータの文字列を数字に変更
train["Sex"][train["Sex"] == "male"] = 0
train["Sex"][train["Sex"] == "female"] = 1
train["Embarked"][train["Embarked"] == "S"] = 0
train["Embarked"][train["Embarked"] == "C"] = 1
train["Embarked"][train["Embarked"] == "Q"] = 2

train.head(10)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# ...

# %%
test["Age"] = test["Age"].fillna(test["Age"].median())
test["Sex"][test["Sex"] == "male"] = 0
test["Sex"][test["Sex"] == "female"] = 1
test["Embarked"][test["Embarked"] == "S"] = 0
test["Embarked"][test["Embarked"] == "C"] = 1
test["Embarked"][test["Embarked"] == "Q"] = 2

missing_value(test)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# ...

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name Sex  \
# 0          892       3                              Kelly, Mr. James   0
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)   1
# 2          894       2                     Myles, Mr. Thomas Francis   0
# 3          895       3                              Wirz, Mr. Albert   0
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)   1
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        2
# 1  47.0      1      0   363272   7.0000   NaN        0
# 2  62.0      0      0   240276   9.6875   NaN        2
# 3  27.0      0      0   315154   8.6625   NaN        0
# 4  22.0      1      1  3101298  12.2875   NaN        0

# %%
test.Fare[152] = test.Fare.median()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
missing_value(test)
# Out:
#              欠損数          %
# PassengerId    0   0.000000
# Pclass         0   0.000000
# Name           0   0.000000
# Sex            0   0.000000
# Age            0   0.000000
# SibSp          0   0.000000
# Parch          0   0.000000
# Ticket         0   0.000000
# Fare           0   0.000000
# Cabin        327  78.229665
# Embarked       0   0.000000

# %% [markdown]
# # ③予測モデルの作成

# %%
from sklearn import tree

target = train["Survived"].values
features_one = train[["Pclass", "Sex", "Age", "Fare"]].values

my_tree_one = tree.DecisionTreeClassifier()
my_tree_one = my_tree_one.fit(features_one, target)

test_features = test[["Pclass", "Sex", "Age", "Fare"]].values

my_prediction = my_tree_one.predict(test_features)

# %%
features_one[:4, :5]
# Out:
# array([[3, 0, 22.0, 7.25],
#        [1, 1, 38.0, 71.2833],
#        [3, 1, 26.0, 7.925],
#        [1, 1, 35.0, 53.1]], dtype=object)

# %%
test_features[:418,0]
test_features.shape
# Out:
# (418, 4)

# %%
my_prediction.shape
# Out:
# (418,)

# %%
#Passenger IDの取得
PassengerId = np.array(test["PassengerId"]).astype(int)

#my_predictionとPassengerIDをデータフレームへ落とし込む
my_solution = pd.DataFrame(my_prediction,PassengerId, columns=["Survived"])

#my_tree_one.csvとして書き出し
my_solution.to_csv("my_tree_one.csv", index_label = ["PassengerId"])

# %%
my_solution
# Out:
#       Survived
# 892          0
# 893          0
# 894          1
# 895          1
# 896          1
# 897          0
# 898          0
# 899          0
# 900          1
# 901          0
# 902          0
# 903          0
# 904          1
# 905          1
# 906          1
# 907          1
# 908          0
# 909          1
# 910          1
# 911          0
# 912          0
# 913          1
# 914          1
# 915          0
# 916          1
# 917          0
# 918          1
# 919          1
# 920          1
# 921          0
# ...        ...
# 1280         0
# 1281         0
# 1282         0
# 1283         1
# 1284         1
# 1285         0
# 1286         0
# 1287         1
# 1288         0
# 1289         1
# 1290         0
# 1291         0
# 1292         1
# 1293         0
# 1294         1
# 1295         1
# 1296         0
# 1297         0
# 1298         0
# 1299         0
# 1300         1
# 1301         1
# 1302         1
# 1303         1
# 1304         0
# 1305         0
# ...

# %% [markdown]
# # ④モデルの改善

# %% [markdown]
# # ⑴決定木微調整　& 特徴量追加

# %%
features_two = train[["Pclass", "Sex", "Age", "Fare", "SibSp", "Parch", "Embarked"]].values

max_depth = 10

min_sample_split = 5

my_tree_two = tree.DecisionTreeClassifier(max_depth=max_depth, min_samples_split=min_sample_split, random_state = 1)
my_tree_two = my_tree_two.fit(features_two, target)

# %%
test_features_two = test[["Pclass", "Sex", "Age", "Fare", "SibSp", "Parch", "Embarked"]].values


my_prediction_tree_two = my_tree_two.predict(test_features_two)
PassengerId = np.array(test["PassengerId"]).astype(int)
my_solution_tree_two = pd.DataFrame(my_prediction_tree_two, PassengerId, columns = ["Survived"])
my_solution_tree_two.to_csv("my_tree_two_csv", index_label = ["PassengerId"])

# %%
my_solution_tree_two
# Out:
#       Survived
# 892          0
# 893          0
# 894          0
# 895          0
# 896          1
# 897          0
# 898          0
# 899          0
# 900          1
# 901          0
# 902          0
# 903          0
# 904          1
# 905          0
# 906          1
# 907          1
# 908          0
# 909          0
# 910          1
# 911          0
# 912          1
# 913          1
# 914          1
# 915          1
# 916          1
# 917          0
# 918          1
# 919          0
# 920          0
# 921          0
# ...        ...
# 1280         0
# 1281         0
# 1282         1
# 1283         1
# 1284         1
# 1285         0
# 1286         0
# 1287         1
# 1288         0
# 1289         1
# 1290         0
# 1291         0
# 1292         1
# 1293         0
# 1294         1
# 1295         1
# 1296         0
# 1297         0
# 1298         0
# 1299         0
# 1300         1
# 1301         1
# 1302         1
# 1303         1
# 1304         0
# 1305         0
# ...

# %% [markdown]
# ## ⑵SVM

# %%
from ipywidgets import FloatProgress
from IPython.display import display
from time import sleep

fp = FloatProgress(min=0, max=100)
display(fp)

for i in range(100):
    sleep(0.1)
    fp.value = i

from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

svc = Pipeline([
    ("scaler", StandardScaler()),
    ("svm_clf", SVC(kernel="poly", degree = 2, coef0=2, C=5))
])
svc = svc.fit(features_two, target)
my_pred_svc = svc.predict(test_features_two)
my_pred_svc
PassengerId = np.array(test["PassengerId"]).astype(int)
my_solution_tree_svc = pd.DataFrame(my_pred_svc, PassengerId, columns = ["Survived"])
my_solution_tree_svc.to_csv("my_tree_svc_csv", index_label = ["PassengerId"])

#グリッドサーチ
from sklearn.model_selection import GridSearchCV

for gamma in [0.001,0.01,0.1,1,10,100]:
    for C in [0.001,0.01,0.1,1,10,100]:
        svc.fit(features_two, target)
        score = svm.score(X_test,y_test)
        
        # ベストスコアをセットし、その時にパラメータも保存
        if score > best_score:
            best_score = score
            best_param = {'C':C,'gamma':gamma }

print("ベストスコア:{:.2f}".format(best_score))
print("その時のパラメータ:{}".format(best_param))
# Out:
# FloatProgress(value=0.0)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ## ⑶ランダムフォレスト

# %%
from sklearn.ensemble import RandomForestClassifier

rnd_clf = RandomForestClassifier(n_estimators=500, max_leaf_nodes=20, n_jobs=-1)
rnd_clf .fit(features_two, target)

y_pred_rnd_clf = rnd_clf.predict(test_features_two)

PassengerId = np.array(test["PassengerId"]).astype(int)
my_solution_tree_rfc = pd.DataFrame(y_pred_rnd_clf, PassengerId, columns = ["Survived"])
my_solution_tree_rfc.to_csv("my_tree_rfc_csv", index_label = ["PassengerId"])

# %% [markdown]
# ### 評価用

# %%
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score, recall_score
from sklearn.model_selection import cross_val_score

# %%
#モデル①（特徴量4つ  決定木）

#交差検証
cross_val_score(my_tree_one, features_one, target, scoring = "accuracy")

#再現性・適合性・F1値
my_prediction_target = my_tree_one.predict(features_one)

recall_score(target, my_prediction_target)
precision_score(target, my_prediction_target)
f1_score(target, my_prediction_target)
# Out:
# 0.9701492537313433

# %%
#モデル②（特徴量6つ  決定木）


#交差検証
cross_val_score(my_tree_two, features_two, target, scoring = "accuracy")

#再現性・適合性・F1値
my_prediction_target_two = my_tree_two.predict(features_two)

recall_score(target, my_prediction_target_two)
precision_score(target, my_prediction_target_two)
f1_score(target, my_prediction_target_two)
# Out:
# 0.8679245283018868

# %%
#モデル③（特徴量6つ  SVM）


#交差検証
cross_val_score(svc, features_two, target, scoring = "accuracy")

# #再現性・適合性・F1値
# my_prediction_target_two = my_tree_two.predict(features_two)

# recall_score(target, my_prediction_target_two)
# precision_score(target, my_prediction_target_two)
# f1_score(target, my_prediction_target_two)
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# array([0.81818182, 0.84175084, 0.82154882])

# %%
#モデル④（特徴量6つ  RandomForest）


#交差検証
cross_val_score(rnd_clf, features_two, target, scoring = "accuracy")

# #再現性・適合性・F1値
# my_prediction_target_two = my_tree_two.predict(features_two)

# recall_score(target, my_prediction_target_two)
# precision_score(target, my_prediction_target_two)
# f1_score(target, my_prediction_target_two)
# Out:
# array([0.78787879, 0.82828283, 0.82491582])
